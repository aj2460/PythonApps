# %%
import pandas
import os

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'Geo-coding.ipynb',
#  'Indexing and Slicing.ipynb',
#  'panda1.py',
#  'Reading data files.ipynb',
#  'Sample.csv',
#  'supermarkets.csv',
#  'supermarkets.json',
#  'Updating and Adding columns.ipynb']

# %%
df=pandas.read_json('supermarkets.json')
df
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
import geopy
dir(geopy)
# Out:
# ['ArcGIS',
#  'AzureMaps',
#  'BANFrance',
#  'Baidu',
#  'Bing',
#  'DataBC',
#  'GeoNames',
#  'GeocodeEarth',
#  'GeocodeFarm',
#  'Geolake',
#  'GoogleV3',
#  'Here',
#  'IGNFrance',
#  'LiveAddress',
#  'Location',
#  'MapBox',
#  'Nominatim',
#  'OpenCage',
#  'OpenMapQuest',
#  'Pelias',
#  'Photon',
#  'PickPoint',
#  'Point',
#  'Timezone',
#  'TomTom',
#  'What3Words',
#  'Yandex',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  'compat',
#  'exc',
#  'format',
#  'geocoders',
#  'get_geocoder_for_service',
#  'location',
#  'point',
#  'timezone',
#  'units',
#  'util']

# %%
from geopy.geocoders import Nominatim

# %%
Nominatim?

# %%
nom = Nominatim(user_agent="myApp")

# %%
n=nom.geocode('Kadakkal, Kerala, 691536')
n.latitude
# Out:
# 8.8308845

# %%
location = nom.reverse("8.8506639,76.9234388")
print(location)
# Out:
# Ittiva, Kollam, Kerala, 691536, India

# %%
df['FullAddress']=df['Address']+','+df['City']+','+df['State']+','+ df['Country']
df
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State                                     FullAddress
# 0          CA 94114         3666 21st St,San Francisco,CA 94114,USA
# 1          CA 94119       735 Dolores St,San Francisco,CA 94119,USA
# 2  California 94114  332 Hill St,San Francisco,California 94114,USA
# 3          CA 94114         3995 23rd St,San Francisco,CA 94114,USA
# 4        California    1056 Sanchez St,San Francisco,California,USA
# 5          CA 94114      551 Alvarado St,San Francisco,CA 94114,USA

# %%
df['Coordinates']=df['FullAddress'].apply(nom.geocode)
 

df
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State                                     FullAddress  \
# 0          CA 94114         3666 21st St,San Francisco,CA 94114,USA
# 1          CA 94119       735 Dolores St,San Francisco,CA 94119,USA
# 2  California 94114  332 Hill St,San Francisco,California 94114,USA
# 3          CA 94114         3995 23rd St,San Francisco,CA 94114,USA
# 4        California    1056 Sanchez St,San Francisco,California,USA
# ...

# %%
df['Coordinates']
# Out:
# 0    (3666, 21st Street, Noe Valley, SF, California...
# 1    (735, Dolores Street, Liberty Street Historic ...
# 2    (332, Hill Street, Noe Valley, SF, California,...
# 3    (3995, 23rd Street, Noe Valley, SF, California...
# 4    (1056, Sanchez Street, Noe Valley, SF, Califor...
# 5    (551, Alvarado Street, Noe Valley, SF, Califor...
# Name: Coordinates, dtype: object

# %%
df.Coordinates[0]
# Out:
# Location(3666, 21st Street, Noe Valley, SF, California, 94114, USA, (37.756488877551, -122.429343346939, 0.0))

# %%
df['Latitude']=df['Coordinates'].apply(lambda x: x.latitude if x !=None else None)
df
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State                                     FullAddress  \
# 0          CA 94114         3666 21st St,San Francisco,CA 94114,USA
# 1          CA 94119       735 Dolores St,San Francisco,CA 94119,USA
# 2  California 94114  332 Hill St,San Francisco,California 94114,USA
# 3          CA 94114         3995 23rd St,San Francisco,CA 94114,USA
# 4        California    1056 Sanchez St,San Francisco,California,USA
# ...
