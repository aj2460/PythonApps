# %%
import pandas

# %%
df1=pandas.DataFrame([[12,15,23]],columns=['Bio','Phy','Che'])
df1
# Out:
#    Bio  Phy  Che
# 0   12   15   23

# %%
df2=pandas.read_csv("E:\\python\\python appTut\\Pandas\sample.csv")
df2
# Out:
#   Start Date   Start Time  End Date    End Time                  Event Title   \
# 0    9/5/2011  3:00:00 PM  9/5/2011         NaN  Social Studies Dept. Meeting
# 1    9/5/2011  6:00:00 PM  9/5/2011  8:00:00 PM            Curriculum Meeting
#
#   All Day Event No End Time   Event Description         Contact   \
# 0             N           Y  Department meeting  Chris Gallagher
# 1             N           N  Curriculum Meeting  Chris Gallagher
#
#                 Contact Email Contact Phone     Location  Category Mandatory  \
# 0  cgallagher@schoolwires.com  814-555-5179  High School         2         N
# 1  cgallagher@schoolwires.com  814-555-5179  High School         2         N
#
#   Registration  Maximum Last Date To Register
# 0            N       25              9/2/2011
# 1            N       25              9/2/2011

# %%
df2.shape
# Out:
# (2, 17)

# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'panda1.py',
#  'Sample.csv',
#  'supermarkets.json',
#  'testing.ipynb']

# %%
df3=pandas.read_json('supermarkets.json')
df3
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
df4=pandas.read_csv('http://pythonhow.com/supermarkets.csv')
df4.set_index('ID')
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20
